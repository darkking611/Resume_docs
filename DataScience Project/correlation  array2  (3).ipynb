# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel (r'C:\Users\pawan tiwari\Desktop\INDIA.xlsx')
#print (df)
sheet_1 = pd.read_excel(r'C:\Users\pawan tiwari\Desktop\INDIA.xlsx',sheet_name = 1)
sheet_2 = pd.read_excel(r'C:\Users\pawan tiwari\Desktop\INDIA.xlsx',sheet_name = 2)
A = sheet_1["Active eonline population"]
C = sheet_2["distance"]
arr1 = sheet_2["Number"]
#sheet_2
#arr1

# %%
M1M2 = []
counter=0
for i in range(len(A)):
    for j in range(len(A)):
        if(i!=j):
            M1M2.append(A[i]*A[j])
            k=i+j-1
            print(M1M2[k])
            counter=counter+1
print(counter)
# Out:
# 1454603
# 23782
# 298544
# 310200
# 281060
# 7144
# 23547
# 4117811
# 21197
# 1668453
# 1935460
# 762904
# 395364
# 269216
# 691088
# 452986
# 1034
# 1689932
# 4130360
# 16967
# 10669
# 16732
# 18800
# 351983
# 65800
# 2133612
# 1381753
# 28341
# 3542954
# 16732
# 3800138
# 114962
# 1510345
# 1454603
# 298544
# 310200
# 281060
# 7144
# 23547
# 4117811
# 21197
# 1668453
# 1935460
# 762904
# 395364
# 269216
# 691088
# 452986
# 1034
# 1689932
# 4130360
# 16967
# 10669
# 16732
# 18800
# 351983
# 65800
# 2133612
# 1381753
# 28341
# 3542954
# 16732
# 3800138
# 114962
# 1510345
# 1454603
# 23782
# 298544
# 281060
# 7144
# 23547
# 4117811
# 21197
# 1668453
# 1935460
# 762904
# 395364
# 269216
# 691088
# 452986
# 1034
# 1689932
# 4130360
# 16967
# 10669
# 16732
# 18800
# 351983
# 65800
# 2133612
# 1381753
# 28341
# 3542954
# 16732
# 3800138
# 114962
# 1510345
# 1454603
# 15660194
# 298544
# 310200
# 281060
# 23547
# 4117811
# 21197
# 1668453
# 1935460
# 762904
# 395364
# 269216
# 691088
# ...

# %%
counter=0
for i in range(len(A)):
    counter=counter+1
print(counter)
# Out:
# 34

# %%
arr2 = []
for i in range(len(M1M2)):
    arr2.append(M1M2[i]/C[i])
    print(arr2[i])
# Out:
# 1409.515760484754
# 22.36282573986271
# 299.24745549726384
# 287.0779314552128
# 297.5440704294209
# 4.967485187265224
# 10.763713970411947
# 2674.546627075732
# 16.32829119138216
# 1081.2462683577942
# 1163.7586147242428
# 457.53043190571583
# 206.75423330586202
# 285.9710147396289
# 672.5140098964761
# 413.1766629564526
# 0.7568513483492595
# 1313.3832316967755
# 2911.370834144336
# 18.70934735117578
# 11.131195944561538
# 20.145176972077383
# 19.444348748289137
# 470.47363196184773
# 75.26393125490138
# 1282.9039843133007
# 908.979933391092
# 25.52408891313601
# 4182.137809301674
# 19.866696576222324
# 2932.6993165724443
# 72.16753507420474
# 1878.8462454410908
# 1409.515760484754
# 13295.19093204338
# 187875.75363330176
# 287490.30843789596
# 549362.916910066
# 11462.686203887522
# 12437.384799578656
# 3471906.174563349
# 41806.20972834031
# 1988190.6178469362
# 1376881.005959115
# 529142.8988743158
# 222017.0529677337
# 292208.8089657352
# 1482158.7344022875
# ...

# %%
print(np.corrcoef(arr1, arr2)[0,1])
# Out:
# 0.6689937371232214

# %%
from pydoc import help
from scipy.stats.stats import pearsonr
pearsonr(arr1,arr2)
# Out:
# (0.6689937371232214, 1.7149428785347355e-146)
